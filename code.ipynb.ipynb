# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")



# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

from learntools.core import binder
binder.bind(globals())
from learntools.data_viz_to_coder.ex7 import *
print("Setup Complete")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# Setup Complete
# Setup Complete

# %%
my_filepath = "/kaggle/input/most-streamed-songs-all-time/Features.csv"
my_data = pd.read_csv(my_filepath, index_col="duration")

# %%
my_data.head()
# Out:
#                               id               name  energy  key  loudness  \
# duration
# 3.33      0VjIjW4GlUZAMYd2vXMi3b    Blinding Lights   0.730    1    -5.934
# 3.90      7qiZfU4dY1lWllzX7mPBI3       Shape of You   0.652    1    -3.183
# 3.49      2XU0oxnq2qxCpomAAuJY8K       Dance Monkey   0.588    6    -6.400
# 3.04      7qEHsqek33rTcFNT9PFqLf  Someone You Loved   0.405    1    -5.679
# 3.64      0e7ipj03S05BNilyu5bRzt           Rockstar   0.520    5    -6.136
#
#           mode  speechiness  acousticness  instrumentalness  liveness  \
# duration
# 3.33         1       0.0598       0.00146          0.000095    0.0897
# 3.90         0       0.0802       0.58100          0.000000    0.0931
# 3.49         0       0.0924       0.69200          0.000104    0.1490
# 3.04         1       0.0319       0.75100          0.000000    0.1050
# 3.64         0       0.0712       0.12400          0.000070    0.1310
#
#           valence    tempo  danceability
# duration
# ...

# %%
plt.figure(figsize=(16,6))
plt.title("features of spotify based on the name of the song")
sns.barplot(x=my_data["name"], y=my_data.index)
# Out:
# <AxesSubplot:title={'center':'features of spotify based on the name of the song'}, xlabel='name', ylabel='duration'>

# %%
plt.figure(figsize=(16,6))
plt.title("representing the whole data in single line plot")
sns.lineplot(data=my_data)
# Out:
# <AxesSubplot:title={'center':'representing the whole data in single line plot'}, xlabel='duration'>

# %%
plt.figure(figsize=(16,6))
plt.title("features of spotify based on the name of the song")
sns.scatterplot(x=my_data['energy'], y=my_data['loudness'], hue=my_data['name'])
# Out:
# <AxesSubplot:title={'center':'features of spotify based on the name of the song'}, xlabel='energy', ylabel='loudness'>
